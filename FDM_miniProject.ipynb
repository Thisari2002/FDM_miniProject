# %% [markdown]
# <a href="https://colab.research.google.com/github/Thisari2002/FDM_miniProject/blob/main/FDM_miniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/content/drugSensitivity.csv')
dataset.head(3)
# Out:
#    COSMIC_ID CELL_LINE_NAME     TCGA_DESC  DRUG_ID    DRUG_NAME   LN_IC50  \
# 0     924186            KGN  UNCLASSIFIED     1006   Cytarabine -1.370897
# 1     907064        HT-1080  UNCLASSIFIED     1613       VE-822  4.456730
# 2     925347     PANC-08-13          PAAD     1062  Selumetinib  4.604022
#
#         AUC   Z_SCORE GDSC Tissue descriptor 1 GDSC Tissue descriptor 2  \
# 0  0.662249 -1.285923        urogenital_system                    ovary
# 1  0.966289  0.743356              soft_tissue             fibrosarcoma
# 2  0.944950  0.735358                 pancreas                 pancreas
#
#   Cancer Type (matching TCGA label) Microsatellite instability Status (MSI)  \
# 0                               NaN                               MSS/MSI-L
# 1                               NaN                               MSS/MSI-L
# 2                              PAAD                               MSS/MSI-L
#
#   Screen Medium Growth Properties CNA Gene Expression Methylation  \
# ...

# %%
dataset = dataset.drop(['Z_SCORE'], axis = 1)
dataset.head(3)
# Out:
#    COSMIC_ID CELL_LINE_NAME     TCGA_DESC  DRUG_ID    DRUG_NAME   LN_IC50  \
# 0     924186            KGN  UNCLASSIFIED     1006   Cytarabine -1.370897
# 1     907064        HT-1080  UNCLASSIFIED     1613       VE-822  4.456730
# 2     925347     PANC-08-13          PAAD     1062  Selumetinib  4.604022
#
#         AUC GDSC Tissue descriptor 1 GDSC Tissue descriptor 2  \
# 0  0.662249        urogenital_system                    ovary
# 1  0.966289              soft_tissue             fibrosarcoma
# 2  0.944950                 pancreas                 pancreas
#
#   Cancer Type (matching TCGA label) Microsatellite instability Status (MSI)  \
# 0                               NaN                               MSS/MSI-L
# 1                               NaN                               MSS/MSI-L
# 2                              PAAD                               MSS/MSI-L
#
#   Screen Medium Growth Properties CNA Gene Expression Methylation  \
# ...
